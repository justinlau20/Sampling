# %%
import torch
from math import exp
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
from torch.distributions.normal import Normal


from infrastructure import Mixture, Normal, RepeatedSampler, RepeatedSamplerWrapper, RandomWalkGaussianProposal, MALA, ULA, MetropolisHastings

# %%
Target_3 = Mixture([Normal(-10, 1), Normal(-5, 1), Normal(0, 1)], [1, 2, 4])

Target_3.plot_pdf(torch.tensor(np.linspace(-20, 10, 1000)), starting=-10)
# Out:
# (-4*x*exp(25/2)*exp(10*x) - 2*x*exp(5*x) - x*exp(-75/2) - 10*exp(5*x) - 10*exp(-75/2))/(4*exp(25/2)*exp(10*x) + 2*exp(5*x) + exp(-75/2))

# %% [markdown]
# ## std = 1

# %% [markdown]
# Random Walk

# %%
MH = MetropolisHastings(Target_3, RandomWalkGaussianProposal(1))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %%
MH = MetropolisHastings(Target_3, RandomWalkGaussianProposal(1))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %%
MH = MetropolisHastings(Target_3, RandomWalkGaussianProposal(1))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %% [markdown]
# MALA

# %%
MH = MetropolisHastings(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %%
MH = MetropolisHastings(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %%
MH = MetropolisHastings(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %% [markdown]
# ULA

# %%
MH = ULA(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %%
MH = ULA(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %%
MH = ULA(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(2000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %% [markdown]
# ## 10000 samples

# %% [markdown]
# Random Walk

# %%
MH = MetropolisHastings(Target_3, RandomWalkGaussianProposal(1))
MH.sample(10000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %% [markdown]
# MALA

# %%
MH = MetropolisHastings(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(10000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %% [markdown]
# ULA

# %%
MH = ULA(Target_3, MALA(1 / 2, Target_3.score))
MH.sample(10000, torch.tensor(-10), burnin=1000)
MH.plot(window_width=20);

# %% [markdown]
# Temp

# %%
MH = ULA(Target_3, MALA(1 / 10, Target_3.score))
MH.sample(10000, torch.tensor(-10), burnin=100000)
MH.plot(window_width=20);
